# %% [markdown]
# # HDF5 warm up
#
# **Primary Source:** *Python and HDF5* by Andrew Collette, O'Reilly 2013.
#
# <a href="https://www.amazon.com/Python-HDF5-Collette/dp/1449367836/ref=tmm_pap_swatch_0?_encoding=UTF8&qid=&sr="><img src="./img/h5py.jpg"></a>

# %% [markdown]
# *Our first task is to store temperature, wind, rain measurements from two  weather stations (1,2).*

# %% [markdown]
# ### Packages, functions and constant

# %%
import pandas
import h5py
import time
import numpy as np
import os
import sys
import time
import timeit
from datetime import datetime


path_file='' #insert the path of this notebook

# %% [markdown]
# ### Data

# %%
arr_1=np.random.normal(loc=150, scale=5, size=100)
arr_2=np.random.normal(loc=np.pi, scale=5, size=100)
arr_3=np.random.normal(loc=150, scale=5, size=100)
arr_4=np.random.normal(loc=np.pi, scale=5, size=100)

# %% [markdown]
# ### Create the hdf5 file

# %% [raw]
# --series_1- attributes: date,instrument, operator
#     |_energy -attributes: units of measure
#     |_angle- attributes: units of measure
#  --series_2- attributes: date, intrument, operator
#     |_energy -attributes: units of measure
#     |_angle- attributes: units of measure

# %%
f=h5py.File(path_file+"toy_experiment.hdf5",'w')


#define and assign values at the  2 groups 'series', in this way I create automatically also the groups 'series'
f["series_1/energy"]=arr_1
f["series_1/angle"]=arr_2
f["series_2/energy"]=arr_3
f["series_2/angle"]=arr_4

#fix the attributes of the 2 group 'series'
f["series_1"].attrs["date"]=datetime.now().strftime("%Y%m%d")
f["series_1"].attrs["instrument"]='XY'
f["series_1"].attrs["operator"]='Bruce'
f["series_2"].attrs["date"]='20241014'
f["series_2"].attrs["instrument"]='XY'
f["series_2"].attrs["operator"]='Tony'



# assign the attributes at  the 2 group 'series'

f["series_1/energy"].attrs["units"]="keV"
f["series_1/angle"].attrs["units"]="rad"
f["series_2/energy"].attrs["units"]="keV"
f["series_2/angle"].attrs["units"]="rad"

f.close()

# %% [markdown]
# ### Read the hdf5 file we have created

# %%
with h5py.File(path_file+"toy_experiment.hdf5", "r") as f:
    # Print all root level object names (aka keys) 
    # these can be group or dataset names 
    print("Keys: %s" % f.keys())
    # get first object name/key; may or may NOT be a group
    for k in f.keys():
        print(f"{k} => {f[k]}")
    for g in f.keys():
        print("*************************")
        print(g)
        for key, value in f[g].attrs.items():
                   print("%s: %s" % (key, value))
        for k in f[g].keys():
               print(k)
               print(f[g][k])
               dataset=f[g][k]
               print(dataset[0:10])
               print(f"{k} => {f[g][k].attrs.keys()}")
               for key, value in dataset.attrs.items():
                   print("%s: %s" % (key, value))
f.close()
# Out:
# Keys: <KeysViewHDF5 ['series_1', 'series_2']>
# series_1 => <HDF5 group "/series_1" (2 members)>
# series_2 => <HDF5 group "/series_2" (2 members)>
# *************************
# series_1
# date: 20241015
# instrument: XY
# operator: Bruce
# angle
# <HDF5 dataset "angle": shape (100,), type "<f8">
# [-2.91429808  2.90022855  5.79232449  6.30683751  8.6742743   3.37271079
#   0.14884002 -9.03059733 11.8887852   4.47843321]
# angle => <KeysViewHDF5 ['units']>
# units: rad
# energy
# <HDF5 dataset "energy": shape (100,), type "<f8">
# [136.83069729 159.11721028 154.91997737 145.16674403 151.11199007
#  148.65033647 156.64818339 146.26886367 144.81526596 151.6653548 ]
# energy => <KeysViewHDF5 ['units']>
# units: keV
# *************************
# series_2
# date: 20241014
# instrument: XY
# operator: Tony
# angle
# <HDF5 dataset "angle": shape (100,), type "<f8">
# [-11.66671189  -0.94286824   4.56473055   1.24805919   0.59447055
#   -0.79889074  -4.21701615   5.73761091  11.95227928   1.21827822]
# angle => <KeysViewHDF5 ['units']>
# units: rad
# energy
# <HDF5 dataset "energy": shape (100,), type "<f8">
# [140.70648321 150.69417469 154.66123643 153.28250147 151.88173834
#  149.30635602 150.63600661 153.41096566 145.96426178 148.56332767]
# energy => <KeysViewHDF5 ['units']>
# units: keV

# %% [markdown]
# ### Read  a file  hdf5 we don't know

# %% [markdown]
# Let's define an ad hoc function that indirectly retrieve the type of an object and at each step try to find out all the attributes.

# %%
def query(f):
    try:  
        f.dtype
        dataset=f
        print("*************************")
        print(f)
        print(' is a dataset')
        
        print('Attributes :')
        for key, value in f.attrs.items():
                   print("%s: %s" % (key, value))  
        ty='d'
        
    except:  
      
     print(' is a group')   
     print('Attributes :')
     for key, value in f.attrs.items():
                print("%s: %s" % (key, value))
     ty='g'
      
     l_g=[]
     for g in f.keys():
         l_g.append(g)
         
     print('tree')
     print(l_g)
     print("*************************")    
     for g in f.keys():
        print('it comes from') 
        print(f)  
        print('__________________') 
        
        print(g)
        o=f[g]
        query(o)   
    return ty

# %% [markdown]
# We will read a nxs file (that is nothing else that a hdf5 with a defined structure). This is not the smartest way to read a nxs (we will see) but take it as exercise.

# %%
start1=  time.perf_counter()
with h5py.File(path_file+"2024_03_06_0006.nxs", "r") as f:
    for k in f.keys():
    # Print all root level object names (aka keys) 
    # these can be group or dataset names 
    
    # get first object name/key; may or may NOT be a group
      i=f[k]  
      print(str(k))
      print(str(i))
      query(i)
    
f.close()  
end1=  time.perf_counter()
t1=end1-start1
# Out:
# entry
# <HDF5 group "/entry" (12 members)>
#  is a group
# Attributes :
# NX_class: NXentry
# tree
# ['data', 'definition', 'duration', 'end_time', 'entry_identifier', 'instrument', 'number_of_scans', 'sample', 'start_time', 'technique', 'title ', 'user']
# *************************
# it comes from
# <HDF5 group "/entry" (12 members)>
# __________________
# data
#  is a group
# Attributes :
# NX_class: NXdata
# axes: energy
# signal: processed_data_sum
# tree
# ['energy', 'incoming_beam', 'incoming_beam_sum', 'mode', 'processed_data', 'processed_data_sum', 'reference_current', 'reference_current_sum', 'sample_current', 'sample_current_sum']
# *************************
# it comes from
# <HDF5 group "/entry/data" (10 members)>
# __________________
# energy
# *************************
# <HDF5 dataset "energy": shape (201,), type "<f8">
#  is a dataset
# Attributes :
# description: Photon energy selected
# target: /entry/instrument/monochromator/energy
# units: eV
# it comes from
# <HDF5 group "/entry/data" (10 members)>
# __________________
# incoming_beam
# *************************
# <HDF5 dataset "incoming_beam": shape (201, 3), type "<f8">
#  is a dataset
# Attributes :
# description: Current at the entry of the endstation, measured from a tantalum (Ta) mesh covered with 200 nm of gold (Au), after the interaction with the X-ray beam
# target: /entry/instrument/incoming_beam_picoammeter/data
# units: A
# it comes from
# <HDF5 group "/entry/data" (10 members)>
# __________________
# incoming_beam_sum
# *************************
# <HDF5 dataset "incoming_beam_sum": shape (201,), type "<f8">
#  is a dataset
# Attributes :
# description: Sum of multiple incoming_beam
# units: A
# it comes from
# <HDF5 group "/entry/data" (10 members)>
# __________________
# mode
# *************************
# <HDF5 dataset "mode": shape (), type "|O">
#  is a dataset
# Attributes :
# it comes from
# <HDF5 group "/entry/data" (10 members)>
# __________________
# processed_data
# *************************
# <HDF5 dataset "processed_data": shape (201, 3), type "<f8">
#  is a dataset
# Attributes :
# description: sample_current / incoming_beam
# units: A/A
# it comes from
# <HDF5 group "/entry/data" (10 members)>
# __________________
# processed_data_sum
# *************************
# <HDF5 dataset "processed_data_sum": shape (201,), type "<f8">
#  is a dataset
# Attributes :
# description: Sum of multiple processed_data
# units: A/A
# it comes from
# <HDF5 group "/entry/data" (10 members)>
# __________________
# reference_current
# *************************
# <HDF5 dataset "reference_current": shape (201, 3), type "<f8">
#  is a dataset
# Attributes :
# description: Current measured on the reference powder after the interaction with the X-ray beam
# target: /entry/instrument/reference_current_picoammeter/data
# units: A
# it comes from
# <HDF5 group "/entry/data" (10 members)>
# __________________
# reference_current_sum
# *************************
# <HDF5 dataset "reference_current_sum": shape (201,), type "<f8">
#  is a dataset
# Attributes :
# description: Sum of multiple reference_current
# units: A
# it comes from
# <HDF5 group "/entry/data" (10 members)>
# __________________
# sample_current
# *************************
# <HDF5 dataset "sample_current": shape (201, 3), type "<f8">
#  is a dataset
# Attributes :
# description: Current measured from the sample after the interaction with the X-ray beam
# target: /entry/instrument/sample_current_picoammeter/data
# units: A
# it comes from
# <HDF5 group "/entry/data" (10 members)>
# __________________
# sample_current_sum
# *************************
# <HDF5 dataset "sample_current_sum": shape (201,), type "<f8">
#  is a dataset
# Attributes :
# description: Sum of multiple sample_current
# units: A
# it comes from
# <HDF5 group "/entry" (12 members)>
# __________________
# definition
# *************************
# <HDF5 dataset "definition": shape (), type "|O">
#  is a dataset
# Attributes :
# it comes from
# <HDF5 group "/entry" (12 members)>
# __________________
# duration
# *************************
# <HDF5 dataset "duration": shape (), type "|O">
#  is a dataset
# Attributes :
# description: Duration of single scan
# units: s
# it comes from
# <HDF5 group "/entry" (12 members)>
# __________________
# end_time
# *************************
# <HDF5 dataset "end_time": shape (), type "|O">
#  is a dataset
# Attributes :
# description: ISO8601 date/time stamp [YYYY]-[MM]-[DD]T[hh]:[mm]:[ss]�[hh]:[mm]
# it comes from
# <HDF5 group "/entry" (12 members)>
# __________________
# entry_identifier
# *************************
# <HDF5 dataset "entry_identifier": shape (), type "|O">
#  is a dataset
# Attributes :
# description: Experiment number automatically assigned by the software
# it comes from
# <HDF5 group "/entry" (12 members)>
# __________________
# instrument
#  is a group
# Attributes :
# NX_class: NXinstrument
# tree
# ['exit_slit', 'incoming_beam_picoammeter', 'monochromator', 'prefocusing_mirror', 'reference_current_picoammeter', 'sample_current_picoammeter', 'source', 'undulator']
# *************************
# it comes from
# <HDF5 group "/entry/instrument" (8 members)>
# __________________
# exit_slit
#  is a group
# Attributes :
# NX_class: NXslit
# tree
# ['gap']
# *************************
# it comes from
# <HDF5 group "/entry/instrument/exit_slit" (1 members)>
# __________________
# gap
# *************************
# <HDF5 dataset "gap": shape (), type "|O">
#  is a dataset
# Attributes :
# units: mm
# it comes from
# <HDF5 group "/entry/instrument" (8 members)>
# __________________
# incoming_beam_picoammeter
#  is a group
# Attributes :
# NX_class: NXdetector
# tree
# ['data', 'description', 'picoammeter_current_range']
# *************************
# it comes from
# <HDF5 group "/entry/instrument/incoming_beam_picoammeter" (3 members)>
# __________________
# data
# *************************
# <HDF5 dataset "data": shape (201, 3), type "<f8">
#  is a dataset
# Attributes :
# description: Current at the entry of the endstation, measured from a tantalum (Ta) mesh covered with 200 nm of gold (Au), after the interaction with the X-ray beam
# target: /entry/instrument/incoming_beam_picoammeter/data
# units: A
# it comes from
# <HDF5 group "/entry/instrument/incoming_beam_picoammeter" (3 members)>
# __________________
# description
# *************************
# <HDF5 dataset "description": shape (), type "|O">
#  is a dataset
# Attributes :
# it comes from
# <HDF5 group "/entry/instrument/incoming_beam_picoammeter" (3 members)>
# __________________
# picoammeter_current_range
# *************************
# <HDF5 dataset "picoammeter_current_range": shape (), type "|O">
#  is a dataset
# Attributes :
# units: nA
# it comes from
# <HDF5 group "/entry/instrument" (8 members)>
# __________________
# monochromator
#  is a group
# Attributes :
# NX_class: NXmonochromator
# tree
# ['energy', 'grating', 'integration_time']
# *************************
# it comes from
# <HDF5 group "/entry/instrument/monochromator" (3 members)>
# __________________
# energy
# *************************
# <HDF5 dataset "energy": shape (201,), type "<f8">
#  is a dataset
# Attributes :
# description: Photon energy selected
# target: /entry/instrument/monochromator/energy
# units: eV
# it comes from
# <HDF5 group "/entry/instrument/monochromator" (3 members)>
# __________________
# grating
#  is a group
# Attributes :
# NX_class: NXgrating
# tree
# ['mirror', 'period']
# *************************
# it comes from
# <HDF5 group "/entry/instrument/monochromator/grating" (2 members)>
# __________________
# mirror
# *************************
# <HDF5 dataset "mirror": shape (), type "|O">
#  is a dataset
# Attributes :
# it comes from
# <HDF5 group "/entry/instrument/monochromator/grating" (2 members)>
# __________________
# period
# *************************
# <HDF5 dataset "period": shape (), type "|O">
#  is a dataset
# Attributes :
# units: lines/mm
# it comes from
# <HDF5 group "/entry/instrument/monochromator" (3 members)>
# __________________
# integration_time
# *************************
# <HDF5 dataset "integration_time": shape (), type "|O">
#  is a dataset
# Attributes :
# description: This parameter defines the acquisition speed of the scan. Lower integration times will result in faster acquisitions with a lower signal-to-noise ratio (SNR) while higher integration times will increase the SNR at the price of slower acquisitions
# units: ms
# it comes from
# <HDF5 group "/entry/instrument" (8 members)>
# __________________
# prefocusing_mirror
#  is a group
# Attributes :
# NX_class: NXmirror
# tree
# ['description', 'incident_angle', 'motor3_encoder_position', 'motor4_encoder_position', 'pressure', 'temperature']
# *************************
# it comes from
# <HDF5 group "/entry/instrument/prefocusing_mirror" (6 members)>
# __________________
# description
# *************************
# <HDF5 dataset "description": shape (), type "|O">
#  is a dataset
# Attributes :
# it comes from
# <HDF5 group "/entry/instrument/prefocusing_mirror" (6 members)>
# __________________
# incident_angle
# *************************
# <HDF5 dataset "incident_angle": shape (), type "|O">
#  is a dataset
# Attributes :
# units: �
# it comes from
# <HDF5 group "/entry/instrument/prefocusing_mirror" (6 members)>
# __________________
# motor3_encoder_position
# *************************
# <HDF5 dataset "motor3_encoder_position": shape (), type "|O">
#  is a dataset
# Attributes :
# units: mm
# it comes from
# <HDF5 group "/entry/instrument/prefocusing_mirror" (6 members)>
# __________________
# motor4_encoder_position
# *************************
# <HDF5 dataset "motor4_encoder_position": shape (), type "|O">
#  is a dataset
# Attributes :
# units: mm
# it comes from
# <HDF5 group "/entry/instrument/prefocusing_mirror" (6 members)>
# __________________
# pressure
# *************************
# <HDF5 dataset "pressure": shape (), type "|O">
#  is a dataset
# Attributes :
# units: mbar
# it comes from
# <HDF5 group "/entry/instrument/prefocusing_mirror" (6 members)>
# __________________
# temperature
# *************************
# <HDF5 dataset "temperature": shape (), type "|O">
#  is a dataset
# Attributes :
# units: �C
# it comes from
# <HDF5 group "/entry/instrument" (8 members)>
# __________________
# reference_current_picoammeter
#  is a group
# Attributes :
# NX_class: NXdetector
# tree
# ['data', 'description', 'picoammeter_current_range']
# *************************
# it comes from
# <HDF5 group "/entry/instrument/reference_current_picoammeter" (3 members)>
# __________________
# data
# *************************
# <HDF5 dataset "data": shape (201, 3), type "<f8">
#  is a dataset
# Attributes :
# description: Current measured on the reference powder after the interaction with the X-ray beam
# target: /entry/instrument/reference_current_picoammeter/data
# units: A
# it comes from
# <HDF5 group "/entry/instrument/reference_current_picoammeter" (3 members)>
# __________________
# description
# *************************
# <HDF5 dataset "description": shape (), type "|O">
#  is a dataset
# Attributes :
# it comes from
# <HDF5 group "/entry/instrument/reference_current_picoammeter" (3 members)>
# __________________
# picoammeter_current_range
# *************************
# <HDF5 dataset "picoammeter_current_range": shape (), type "|O">
#  is a dataset
# Attributes :
# units: nA
# it comes from
# <HDF5 group "/entry/instrument" (8 members)>
# __________________
# sample_current_picoammeter
#  is a group
# Attributes :
# NX_class: NXdetector
# tree
# ['data', 'description', 'picoammeter_current_range']
# *************************
# it comes from
# <HDF5 group "/entry/instrument/sample_current_picoammeter" (3 members)>
# __________________
# data
# *************************
# <HDF5 dataset "data": shape (201, 3), type "<f8">
#  is a dataset
# Attributes :
# description: Current measured from the sample after the interaction with the X-ray beam
# target: /entry/instrument/sample_current_picoammeter/data
# units: A
# it comes from
# <HDF5 group "/entry/instrument/sample_current_picoammeter" (3 members)>
# __________________
# description
# *************************
# <HDF5 dataset "description": shape (), type "|O">
#  is a dataset
# Attributes :
# it comes from
# <HDF5 group "/entry/instrument/sample_current_picoammeter" (3 members)>
# __________________
# picoammeter_current_range
# *************************
# <HDF5 dataset "picoammeter_current_range": shape (), type "|O">
#  is a dataset
# Attributes :
# units: nA
# it comes from
# <HDF5 group "/entry/instrument" (8 members)>
# __________________
# source
#  is a group
# Attributes :
# NX_class: NXsource
# tree
# ['current', 'energy', 'name', 'probe', 'type']
# *************************
# it comes from
# <HDF5 group "/entry/instrument/source" (5 members)>
# __________________
# current
# *************************
# <HDF5 dataset "current": shape (), type "|O">
#  is a dataset
# Attributes :
# description: Ring current
# units: mA
# it comes from
# <HDF5 group "/entry/instrument/source" (5 members)>
# __________________
# energy
# *************************
# <HDF5 dataset "energy": shape (), type "|O">
#  is a dataset
# Attributes :
# description: Beam energy
# units: GeV
# it comes from
# <HDF5 group "/entry/instrument/source" (5 members)>
# __________________
# name
# *************************
# <HDF5 dataset "name": shape (), type "|O">
#  is a dataset
# Attributes :
# it comes from
# <HDF5 group "/entry/instrument/source" (5 members)>
# __________________
# probe
# *************************
# <HDF5 dataset "probe": shape (), type "|O">
#  is a dataset
# Attributes :
# it comes from
# <HDF5 group "/entry/instrument/source" (5 members)>
# __________________
# type
# *************************
# <HDF5 dataset "type": shape (), type "|O">
#  is a dataset
# Attributes :
# it comes from
# <HDF5 group "/entry/instrument" (8 members)>
# __________________
# undulator
#  is a group
# Attributes :
# NX_class: NXinsertion_device
# tree
# ['gap', 'magnetic_wavelength', 'phase', 'type']
# *************************
# it comes from
# <HDF5 group "/entry/instrument/undulator" (4 members)>
# __________________
# gap
# *************************
# <HDF5 dataset "gap": shape (), type "|O">
#  is a dataset
# Attributes :
# units: mm
# it comes from
# <HDF5 group "/entry/instrument/undulator" (4 members)>
# __________________
# magnetic_wavelength
# *************************
# <HDF5 dataset "magnetic_wavelength": shape (), type "|O">
#  is a dataset
# Attributes :
# units: cm
# it comes from
# <HDF5 group "/entry/instrument/undulator" (4 members)>
# __________________
# phase
# *************************
# <HDF5 dataset "phase": shape (), type "|O">
#  is a dataset
# Attributes :
# units: mm
# it comes from
# <HDF5 group "/entry/instrument/undulator" (4 members)>
# __________________
# type
# *************************
# <HDF5 dataset "type": shape (), type "|O">
#  is a dataset
# Attributes :
# it comes from
# <HDF5 group "/entry" (12 members)>
# __________________
# number_of_scans
# *************************
# <HDF5 dataset "number_of_scans": shape (), type "|O">
#  is a dataset
# Attributes :
# it comes from
# <HDF5 group "/entry" (12 members)>
# __________________
# sample
#  is a group
# Attributes :
# NX_class: NXsample
# tree
# ['chemical_formula', 'end_temperature', 'gas_flux_C2H4', 'gas_flux_CO', 'gas_flux_He', 'name', 'pressure', 'situation', 'start_temperature', 'transformations']
# *************************
# it comes from
# <HDF5 group "/entry/sample" (10 members)>
# __________________
# chemical_formula
# *************************
# <HDF5 dataset "chemical_formula": shape (), type "|O">
#  is a dataset
# Attributes :
# it comes from
# <HDF5 group "/entry/sample" (10 members)>
# __________________
# end_temperature
# *************************
# <HDF5 dataset "end_temperature": shape (), type "|O">
#  is a dataset
# Attributes :
# units: K
# it comes from
# <HDF5 group "/entry/sample" (10 members)>
# __________________
# gas_flux_C2H4
# *************************
# <HDF5 dataset "gas_flux_C2H4": shape (), type "|O">
#  is a dataset
# Attributes :
# units: ml/min
# it comes from
# <HDF5 group "/entry/sample" (10 members)>
# __________________
# gas_flux_CO
# *************************
# <HDF5 dataset "gas_flux_CO": shape (), type "|O">
#  is a dataset
# Attributes :
# units: ml/min
# it comes from
# <HDF5 group "/entry/sample" (10 members)>
# __________________
# gas_flux_He
# *************************
# <HDF5 dataset "gas_flux_He": shape (), type "|O">
#  is a dataset
# Attributes :
# units: ml/min
# it comes from
# <HDF5 group "/entry/sample" (10 members)>
# __________________
# name
# *************************
# <HDF5 dataset "name": shape (), type "|O">
#  is a dataset
# Attributes :
# description: Descriptive name of the sample or sample ID, if provided by the ELN
# it comes from
# <HDF5 group "/entry/sample" (10 members)>
# __________________
# pressure
# *************************
# <HDF5 dataset "pressure": shape (), type "|O">
#  is a dataset
# Attributes :
# units: mbar
# it comes from
# <HDF5 group "/entry/sample" (10 members)>
# __________________
# situation
# *************************
# <HDF5 dataset "situation": shape (), type "|O">
#  is a dataset
# Attributes :
# it comes from
# <HDF5 group "/entry/sample" (10 members)>
# __________________
# start_temperature
# *************************
# <HDF5 dataset "start_temperature": shape (), type "|O">
#  is a dataset
# Attributes :
# units: K
# it comes from
# <HDF5 group "/entry/sample" (10 members)>
# __________________
# transformations
#  is a group
# Attributes :
# NX_class: NXtransformations
# tree
# ['x', 'y', 'z']
# *************************
# it comes from
# <HDF5 group "/entry/sample/transformations" (3 members)>
# __________________
# x
# *************************
# <HDF5 dataset "x": shape (1,), type "<f8">
#  is a dataset
# Attributes :
# description: Axis along the beam direction
# target: /entry/sample/transformations/x
# units: mm
# it comes from
# <HDF5 group "/entry/sample/transformations" (3 members)>
# __________________
# y
# *************************
# <HDF5 dataset "y": shape (1,), type "<f8">
#  is a dataset
# Attributes :
# description: Axis perpendicular to the beam
# target: /entry/sample/transformations/y
# units: mm
# it comes from
# <HDF5 group "/entry/sample/transformations" (3 members)>
# __________________
# z
# *************************
# <HDF5 dataset "z": shape (1,), type "<f8">
#  is a dataset
# Attributes :
# description: Axis along the vertical direction
# target: /entry/sample/transformations/z
# units: mm
# it comes from
# <HDF5 group "/entry" (12 members)>
# __________________
# start_time
# *************************
# <HDF5 dataset "start_time": shape (), type "|O">
#  is a dataset
# Attributes :
# description: ISO8601 date/time stamp [YYYY]-[MM]-[DD]T[hh]:[mm]:[ss]�[hh]:[mm]
# it comes from
# <HDF5 group "/entry" (12 members)>
# __________________
# technique
# *************************
# <HDF5 dataset "technique": shape (), type "|O">
#  is a dataset
# Attributes :
# it comes from
# <HDF5 group "/entry" (12 members)>
# __________________
# title
# *************************
# <HDF5 dataset "title ": shape (), type "|O">
#  is a dataset
# Attributes :
# it comes from
# <HDF5 group "/entry" (12 members)>
# __________________
# user
#  is a group
# Attributes :
# NX_class: NXuser
# tree
# ['affiliation', 'email', 'name ']
# *************************
# it comes from
# <HDF5 group "/entry/user" (3 members)>
# __________________
# affiliation
# *************************
# <HDF5 dataset "affiliation": shape (), type "|O">
#  is a dataset
# Attributes :
# it comes from
# <HDF5 group "/entry/user" (3 members)>
# __________________
# email
# *************************
# <HDF5 dataset "email": shape (), type "|O">
#  is a dataset
# Attributes :
# it comes from
# <HDF5 group "/entry/user" (3 members)>
# __________________
# name
# *************************
# <HDF5 dataset "name ": shape (), type "|O">
#  is a dataset
# Attributes :

# %% [markdown]
# Function to navigate across the file

# %%
f=h5py.File(path_file+"2024_03_06_0006.nxs", "r") 

for name in f:
    print( f.get(name,getclass=True))
def printname(name):
    print(name)
   
f.visit(printname) 

print('************')
f['entry/data'].visit(printname)
# Out:
# <class 'h5py._hl.group.Group'>
# entry
# entry/data
# entry/data/energy
# entry/data/incoming_beam
# entry/data/incoming_beam_sum
# entry/data/mode
# entry/data/processed_data
# entry/data/processed_data_sum
# entry/data/reference_current
# entry/data/reference_current_sum
# entry/data/sample_current
# entry/data/sample_current_sum
# entry/definition
# entry/duration
# entry/end_time
# entry/entry_identifier
# entry/instrument
# entry/instrument/exit_slit
# entry/instrument/exit_slit/gap
# entry/instrument/incoming_beam_picoammeter
# entry/instrument/incoming_beam_picoammeter/data
# entry/instrument/incoming_beam_picoammeter/description
# entry/instrument/incoming_beam_picoammeter/picoammeter_current_range
# entry/instrument/monochromator
# entry/instrument/monochromator/energy
# entry/instrument/monochromator/grating
# entry/instrument/monochromator/grating/mirror
# entry/instrument/monochromator/grating/period
# entry/instrument/monochromator/integration_time
# entry/instrument/prefocusing_mirror
# entry/instrument/prefocusing_mirror/description
# entry/instrument/prefocusing_mirror/incident_angle
# entry/instrument/prefocusing_mirror/motor3_encoder_position
# entry/instrument/prefocusing_mirror/motor4_encoder_position
# entry/instrument/prefocusing_mirror/pressure
# entry/instrument/prefocusing_mirror/temperature
# entry/instrument/reference_current_picoammeter
# entry/instrument/reference_current_picoammeter/data
# entry/instrument/reference_current_picoammeter/description
# entry/instrument/reference_current_picoammeter/picoammeter_current_range
# entry/instrument/sample_current_picoammeter
# entry/instrument/sample_current_picoammeter/data
# entry/instrument/sample_current_picoammeter/description
# entry/instrument/sample_current_picoammeter/picoammeter_current_range
# entry/instrument/source
# entry/instrument/source/current
# entry/instrument/source/energy
# entry/instrument/source/name
# entry/instrument/source/probe
# entry/instrument/source/type
# entry/instrument/undulator
# entry/instrument/undulator/gap
# entry/instrument/undulator/magnetic_wavelength
# entry/instrument/undulator/phase
# entry/instrument/undulator/type
# entry/number_of_scans
# entry/sample
# entry/sample/chemical_formula
# entry/sample/end_temperature
# entry/sample/gas_flux_C2H4
# entry/sample/gas_flux_CO
# entry/sample/gas_flux_He
# entry/sample/name
# entry/sample/pressure
# entry/sample/situation
# entry/sample/start_temperature
# entry/sample/transformations
# entry/sample/transformations/x
# entry/sample/transformations/y
# entry/sample/transformations/z
# entry/start_time
# entry/technique
# entry/title
# entry/user
# entry/user/affiliation
# entry/user/email
# entry/user/name
# ************
# energy
# incoming_beam
# incoming_beam_sum
# mode
# processed_data
# processed_data_sum
# reference_current
# reference_current_sum
# sample_current
# sample_current_sum
